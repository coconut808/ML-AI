# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data/ITSM_Data.xlsx')
df.head()
# Out:
#    ID_request                                               Text Category  \
# 0        2913                                      Discord issue  Discord
# 1        2691            I need to install Discord on my new PC.  Discord
# 2        3395  Discord disappeared from laptop after I update...  Discord
# 3        2380  Discord is very slow while other applications ...  Discord
# 4        4999                     Discor needed for instalation.  Discord
#
#                         Solution Date_request_recieved Date_request_solved  \
# 0                 Problem solved            2022-10-03          2022-10-03
# 1              Discord Installed            2022-10-08          2022-10-10
# 2              Discord Installed            2022-10-17          2022-10-17
# 3  Software updated, PC cleaned.            2022-10-11          2022-10-11
# 4                 Problem solved            2022-10-04          2022-10-04
#
#    ID_agent
# 0         3
# 1         1
# 2         3
# 3         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID_request             118 non-null    int64
#  1   Text                   117 non-null    object
#  2   Category               115 non-null    object
#  3   Solution               115 non-null    object
#  4   Date_request_recieved  118 non-null    datetime64[ns]
#  5   Date_request_solved    118 non-null    datetime64[ns]
#  6   ID_agent               118 non-null    int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 6.6+ KB

# %%
#Filter out discord related issues
df[~df['Text'].str.contains('Discord', case=False, na=False)]
# Out:
#      ID_request                                               Text   Category  \
# 4          4999                     Discor needed for instalation.    Discord
# 7          4069                               Installation needed.    Discord
# 15         2220                                                NaN    Discord
# 16         1308  Asana ist das beste Tool für das Projektmanage...      Asana
# 17         1089  Bitte installieren Sie Asana erneut auf meinem...      Asana
# ..          ...                                                ...        ...
# 113        2455  Ich möchte eine zusätzliche Tastatur bestellen...  Keyboard
# 114        3853  Der Tastaturaustausch ist erforderlich. Bitte ...  Keyboard
# 115        4541  I would like to order the new keyboard for pre...  Keyboard
# 116        1937  Please send the new keyboard to my home addres...  Keyboard
# 117        4878  Please send the new keyboard to my home addres...  Keyboard
#
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Outlook             22
# Discord             16
# CRM                 14
# Internet Browser    12
# Mail                11
# Keyboard            11
# Asana               10
# Mouse               10
# Help Needed          9
# Name: count, dtype: int64

# %%
df[df['Category'] == 'CRM']
# Out:
#     ID_request                                               Text Category  \
# 69        4663   Our CRM stopped to work again. I can't start it.      CRM
# 70        4884  Can't Edit customer field in our CRM. Please f...      CRM
# 71        2993  Hubspot CRM funktioniert überhaupt nicht. Bitt...      CRM
# 72        3348  <p>Can't start Salesforce CRM. Please fix this...      CRM
# 73        2882  CRM funktioniert nach dem letzten Windows-Upda...      CRM
# 74        2797  Want to add plug-in for Zoom into Hubspot CRM ...      CRM
# 75        1190  I neeed Salesforce CRM on my new laptop. Pleas...      CRM
# 76        2686  Ich brauche Salesforce CRM auf meinem neuen La...      CRM
# 77        2598  I can't adjust any field in CRM, and I was abl...      CRM
# 78        1313  CRM doesn't load customer data, I can't work w...      CRM
# 79        3620                         Installation erforderlich.      CRM
# ...

# %%
# Run once if langdetect is not installed
# !pip3 install langdetect

# %%
from langdetect import detect, DetectorFactory
DetectorFactory.seed = 0  # For reproducibility

def detect_language(text):
    try:
        if pd.isna(text) or text.strip() == "":
            return "unknown"
        return detect(text)
    except Exception as e:
        return "error unknown"

# %%
df['language'] = df['Text'].apply(detect_language)
df['language'].value_counts()
# Out:
# language
# en         73
# de         35
# hr          3
# es          2
# unknown     1
# it          1
# sv          1
# no          1
# da          1
# Name: count, dtype: int64

# %%
df3 = df[df['language'] == 'en']

# %%
df3.head()
# Out:
#    ID_request                                               Text Category  \
# 1        2691            I need to install Discord on my new PC.  Discord
# 2        3395  Discord disappeared from laptop after I update...  Discord
# 3        2380  Discord is very slow while other applications ...  Discord
# 4        4999                     Discor needed for instalation.  Discord
# 5        1236  I can't open Discord, it freezes every time I ...  Discord
#
#                         Solution Date_request_recieved Date_request_solved  \
# 1              Discord Installed            2022-10-08          2022-10-10
# 2              Discord Installed            2022-10-17          2022-10-17
# 3  Software updated, PC cleaned.            2022-10-11          2022-10-11
# 4                 Problem solved            2022-10-04          2022-10-04
# 5             Discord installed.            2022-10-19          2022-10-19
#
#    ID_agent language
# 1         1       en
# 2         3       en
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, 1 to 117
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID_request             73 non-null     int64
#  1   Text                   73 non-null     object
#  2   Category               72 non-null     object
#  3   Solution               72 non-null     object
#  4   Date_request_recieved  73 non-null     datetime64[ns]
#  5   Date_request_solved    73 non-null     datetime64[ns]
#  6   ID_agent               73 non-null     int64
#  7   language               73 non-null     object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 5.1+ KB

# %%
itdf = pd.read_csv('data/ITSM_Data.csv')
